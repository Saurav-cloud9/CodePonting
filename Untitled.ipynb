# %%
print("Hello from Jupyter!")
# Out:
# Hello from Jupyter!

# %%
import os
os.getcwd()  # Shows where Jupyter is looking
# Out:
# 'C:\\Users\\Saurav\\CodePonting'

# %%
df = pd.read_csv(r'C:\Users\Saurav\CodePonting\pythonProject\Algo Trading\Equity\Quant_Dev_BOT\Ma_Bounce_Bot_v1\LiveBot_14thJAN\trades_log_master.csv')
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 df = pd.read_csv(r'C:\Users\Saurav\CodePonting\pythonProject\Algo Trading\Equity\Quant_Dev_BOT\Ma_Bounce_Bot_v1\LiveBot_14thJAN\trades_log_master.csv')
#       2 df
#
# ...

# %%
df = pd.read_csv(r'C:\Users\Saurav\CodePonting\pythonProject\Algo Trading\Equity\MA_BOUNCE_BOT\Ma_Bounce_Bot_v1\LiveBot_14thJAN\trades_log_master.csv')
df
# Out:
#              Timestamp      Symbol Side   Price  Quantity  Order_Value  \
# 0  2026-01-14 12:21:18  TATAMOTORS  BUY  353.35         2        706.7
#
#          Strategy  Target  Stop_Loss         Order_ID  Realized_PnL  \
# 0  MORNING_BOUNCE  358.65     351.58  260114000294489           NaN
#
#    Exit_Reason
# 0          NaN

# %%
C:\Users\Saurav\Downloads
# Out:
#   Cell In[6], line 1
#     C:\Users\Saurav\Downloads
#        ^
# SyntaxError: unexpected character after line continuation character

# %%
df = pd.read_csv(r'C:\Users\Saurav\Downloads\NIFTY Trend Health Scanner Test_ScanResults.csv')
df
# Out:
#      Sector             Symbol Exchange       Ltp  %Change  Volume
# 0       NaN           NIFTY 50  INDICES  26179.20    -0.27       0
# 1       NaN  NIFTY MS FIN SERV  INDICES  21047.10     0.20       0
# 2       NaN             OILGAS  INDICES  28210.66    -1.25       0
# 3       NaN             BSE CG  INDICES  67556.07    -0.63       0
# 4       NaN   NIFTY MID SELECT  INDICES  13951.30    -0.12       0
# ..      ...                ...      ...       ...      ...     ...
# 188     NaN  NIFTYM150MOMNTM50  INDICES  62615.45    -0.19       0
# 189     NaN  NIFTY SERV SECTOR  INDICES  33875.65     0.17       0
# 190     NaN  NIFTY200 VALUE 30  INDICES  15027.80    -0.10       0
# 191     NaN       BSE SERVICES  INDICES   1547.59    -1.02       0
# 192     NaN           HANGSENG  INDICES  26710.46     1.38       0
#
# [193 rows x 6 columns]
