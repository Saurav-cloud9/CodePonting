# %%
import pandas as pd

close = pd.Series([225, 210, 222])
prev_close = close.shift(-1)
print(close)
print(prev_close)
# Out:
# 0    225
# 1    210
# 2    222
# dtype: int64
# 0    210.0
# 1    222.0
# 2      NaN
# dtype: float64
