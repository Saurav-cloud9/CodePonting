# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import plotly.express as px

# %%
df = pd.read_csv(r'C:\Users\Saurav\CodePonting\Learning\Codedex\matplotlib\exercise9.csv')

px.scatter(df['life_expectancy'], df['gdp_per_capita'], size=df['population']/1000000, color=df['country'])
px.scatter(df, x='life_expectancy', y='gdp_per_capita', color='country', size='population', title='life expectancy vs gpd per capita', labels={'life_expectancy': 'Life Expectancy', 'gdp_per_capita': 'GDP Per Capita'})
