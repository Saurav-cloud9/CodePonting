# %%
import numpy as np

# %%
coffee = np.array([3, 2, 1, 0, 1])

# %%
print(coffee[0])
# Out:
# 3

# %%
print(coffee[0:2])
# Out:
# [3 2]

# %%
print(coffee[1:3])
# Out:
# [2 1]

# %%
print(coffee[-3:])
# Out:
# [1 0 1]

# %%
print(coffee[:-2])
# Out:
# [3 2 1]
