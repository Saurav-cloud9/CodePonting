# %% [markdown]
# Instructions
# #30NitesOfCode is a Codédex feature that encourages you to code every day for a month. 🦄
#
# A learner recorded the amount of time they coded every single day for four weeks:
#
# month_results = np.array([56, 100, 33, 0, 45, 45, 46, 34, 89, 180, 60, 45, 45, 44, 46, 45, 0, 0, 15, 90, 301, 197, 20, 60, 45, 45, 42, 45])
#
# Without typing code, what is the shape of this array? Confirm by using the .shape property.
#
# Without typing code, what is the shape of this array? Confirm using the .shape property.
#
# Suppose we want to split this monthly data into weekly data. Use .reshape() so that the array has 4 rows of 7 items (one for each day of the week).
